# %% [markdown]
# # Tutorial
# After setting up an environment and run the `deepsas_v1.py` using the example data:
#
# ```bash
# nohup uv run python -u deepsas_v1.py --output_dir ./outputs --exp_name example --device_index 0 --retrain > ./example.log 2>&1 &
# ```
# The path of output results is:
#
# ```
# ./outputs/example
# ```
#
# Then generate 3 tables of SnGs:
#
# ```bash
# uv run python -u generate_3tables.py --output_dir ./outputs --exp_name example --device_index 0
# ```
#
# The path of those 3 tables is:
#
# ```
# ./outputs/example/Senescent_Tables
# ```
#
#
# Now the mian program of DeepSAS is end. Here is the code for downstream analysis.
#
# **Please note that the default input of DeepSAS is the h5ad file, the default cell type information is stored in `clusters`.**
#
# ## UMAP plot of raw data

# %%
import scanpy as sp
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd
import random
import numpy as np
import umap
import os
import datetime
import torch

from plot_figure import generate_umap,\
                        generate_umap_snc,\
                        bar_plot_condition,\
                        bar_plot_location,\
                        bar_plot_age,\
                        generate_heatmap,\
                        create_summary_table,\
                        preprocess_plot,\
                        load_snc_info,\
                        generate_heatmap_snc
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import scanpy as sp
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/scanpy/__init__.py:16
#      11     except ModuleNotFoundError:
#      12         raise RuntimeError(
#      13             "scanpy is not correctly installed. Please install it, e.g. with pip."
#      14         )
# ---> 16 from ._utils import check_versions
#      18 check_versions()
#      19 del check_versions
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/scanpy/_utils/__init__.py:21
#      19 from numpy import random
#      20 from scipy import sparse
# ---> 21 from anndata import AnnData, __version__ as anndata_version
#      22 from textwrap import dedent
#      23 from packaging import version
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/__init__.py:10
#       8 from ._core.merge import concat
#       9 from ._core.raw import Raw
# ---> 10 from ._io import (
#      11     read_h5ad,
#      12     read_loom,
#      13     read_hdf,
#      14     read_excel,
#      15     read_umi_tools,
#      16     read_csv,
#      17     read_text,
#      18     read_mtx,
#      19     read_zarr,
#      20 )
#      21 from ._warnings import (
#      22     OldFormatWarning,
#      23     WriteWarning,
#      24     ImplicitModificationWarning,
#      25     ExperimentalFeatureWarning,
#      26 )
#      28 # backwards compat / shortcut for default format
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/_io/__init__.py:1
# ----> 1 from .read import (
#       2     read_csv,
#       3     read_excel,
#       4     read_umi_tools,
#       5     read_hdf,
#       6     read_loom,
#       7     read_mtx,
#       8     read_text,
#       9     read_zarr,
#      10     read_h5ad,
#      11 )
#      12 from .write import write_csvs, write_loom, _write_h5ad, write_zarr
#      13 from . import h5ad
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/_io/read.py:19
#      17 from ..compat import _deprecate_positional_args
#      18 from .utils import is_float
# ---> 19 from .h5ad import read_h5ad
#      21 try:
#      22     from .zarr import read_zarr
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/_io/h5ad.py:22
#      16 from .._core.anndata import AnnData
#      17 from ..compat import (
#      18     _from_fixed_length_strings,
#      19     _decode_structured_array,
#      20     _clean_uns,
#      21 )
# ---> 22 from ..experimental import read_dispatched
#      23 from .utils import (
#      24     H5PY_V3,
#      25     report_read_key_on_error,
#    (...)
#      28     _read_legacy_raw,
#      29 )
#      30 from .specs import read_elem, write_elem
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/experimental/__init__.py:7
#       4 from typing import Callable, Any
#       6 from .multi_files import AnnCollection
# ----> 7 from .pytorch import AnnLoader
#       9 from anndata._io.specs import read_elem, write_elem, IOSpec
#      10 from anndata._types import StorageType, GroupStorageType
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/experimental/pytorch/__init__.py:1
# ----> 1 from ._annloader import AnnLoader
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/anndata/experimental/pytorch/_annloader.py:15
#      11 from ..multi_files._anncollection import AnnCollection, _ConcatViewMixin
#      14 try:
# ---> 15     import torch
#      16     from torch.utils.data import Sampler, BatchSampler, Dataset, DataLoader
#      17 except ImportError:
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/__init__.py:2143
#    2141 from . import library
#    2142 if not TYPE_CHECKING:
# -> 2143     from . import _meta_registrations
#    2145 # Enable CUDA Sanitizer
#    2146 if 'TORCH_CUDA_SANITIZER' in os.environ:
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_meta_registrations.py:9
#       7 import torch._prims_common as utils
#       8 from torch import SymBool, SymFloat, Tensor
# ----> 9 from torch._decomp import (
#      10     _add_op_to_registry,
#      11     _convert_out_params,
#      12     global_decomposition_table,
#      13     meta_table,
#      14 )
#      15 from torch._ops import OpOverload
#      16 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_decomp/__init__.py:245
#     241             decompositions.pop(op, None)
#     244 # populate the table
# --> 245 import torch._decomp.decompositions
#     246 import torch._refs
#     249 # See NOTE [Core ATen Ops]
#     250 #
#     251 # list was copied from torch/_inductor/decomposition.py
#     252 # excluding decompositions that results in prim ops
#     253 # Resulting opset of decomposition is core aten ops
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_decomp/decompositions.py:12
#       9 from typing import Any, Callable, cast, Iterable, List, Optional, Tuple, Union
#      11 import torch
# ---> 12 import torch._prims as prims
#      13 import torch._prims_common as utils
#      14 import torch.nn.functional as F
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_prims/__init__.py:504
#     496     raise NotImplementedError
#     499 #
#     500 # Elementwise unary operations
#     501 #
# --> 504 abs = _make_elementwise_unary_prim(
#     505     "abs",
#     506     impl_aten=torch.abs,
#     507     doc="",
#     508     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.COMPLEX_TO_FLOAT,
#     509 )
#     511 acos = _make_elementwise_unary_prim(
#     512     "acos",
#     513     impl_aten=torch.acos,
#     514     doc="",
#     515     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     516 )
#     518 acosh = _make_elementwise_unary_prim(
#     519     "acosh",
#     520     impl_aten=torch.acosh,
#     521     doc="",
#     522     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     523 )
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_prims/__init__.py:472, in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     465 def _make_elementwise_unary_prim(
#     466     name: str, *, type_promotion: ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND, **kwargs
#     467 ):
#     468     """
#     469     Creates an elementwise unary prim.
#     470     """
# --> 472     return _make_prim(
#     473         schema=f"{name}(Tensor self) -> Tensor",
#     474         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#     475         return_type=RETURN_TYPE.NEW,
#     476         **kwargs,
#     477     )
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_prims/__init__.py:320, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api)
#     318         if arg.alias_info is not None and arg.alias_info.is_write:
#     319             mutates_args.append(arg.name)
# --> 320     prim_def = torch.library.custom_op(
#     321         "prims::" + name,
#     322         _prim_impl,
#     323         mutates_args=tuple(mutates_args),
#     324         schema=schema,
#     325     )
#     326     prim_def.register_fake(meta)
#     328 _prim_packet = getattr(torch._ops.ops.prims, name)
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_library/custom_ops.py:142, in custom_op(name, fn, mutates_args, device_types, schema)
#     140 if fn is None:
#     141     return inner
# --> 142 return inner(fn)
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_library/custom_ops.py:123, in custom_op.<locals>.inner(fn)
#     121     schema_str = schema
#     122 namespace, opname = name.split("::")
# --> 123 result = CustomOpDef(namespace, opname, schema_str, fn)
#     124 if schema is not None:
#     125     # Check that schema's alias annotations match those of `mutates_args`.
#     126     expected = set()
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_library/custom_ops.py:169, in CustomOpDef.__init__(self, namespace, name, schema, fn)
#     166 self._backward_fn: Optional[Callable] = None
#     168 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 169 self._register_to_dispatcher()
#     170 OPDEFS[self._qualname] = self
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_library/custom_ops.py:473, in CustomOpDef._register_to_dispatcher(self)
#     465         raise RuntimeError(
#     466             f"There was no fake impl registered for {self}. "
#     467             f"This is necessary for torch.compile/export/fx tracing to work. "
#     468             f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     469             f"fake impl."
#     470         )
#     471     return self._abstract_fn(*args, **kwargs)
# --> 473 lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     475 autograd_impl = _library.autograd.make_autograd_impl(self._opoverload, self)
#     476 lib.impl(self._name, autograd_impl, "Autograd", with_keyset=True)
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/library.py:135, in Library._register_fake(self, op_name, fn, _stacklevel)
#     133 def _register_fake(self, op_name, fn, _stacklevel=1):
#     134     r'''Registers the fake impl for an operator defined in the library.'''
# --> 135     source = torch._library.utils.get_source(_stacklevel + 1)
#     136     frame = sys._getframe(_stacklevel)
#     137     caller_module = inspect.getmodule(frame)
#
# File /fs/scratch/PAS1475/vinson/deepsas_v2/.venv/lib/python3.8/site-packages/torch/_library/utils.py:42, in get_source(stacklevel)
#      33 def get_source(stacklevel: int) -> str:
#      34     """Get a string that represents the caller.
#      35
#      36     Example: "/path/to/foo.py:42"
#    (...)
#      40     etc.
#      41     """
# ---> 42     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      43     source = f"{frame.filename}:{frame.lineno}"
#      44     return source
#
# File ~/.local/share/uv/python/cpython-3.8.20-linux-x86_64-gnu/lib/python3.8/inspect.py:1477, in getframeinfo(frame, context)
#    1475 start = lineno - 1 - context//2
#    1476 try:
# -> 1477     lines, lnum = findsource(frame)
#    1478 except OSError:
#    1479     lines = index = None
#
# File ~/.local/share/uv/python/cpython-3.8.20-linux-x86_64-gnu/lib/python3.8/inspect.py:792, in findsource(object)
#     789     if not (file.startswith('<') and file.endswith('>')):
#     790         raise OSError('source code not available')
# --> 792 module = getmodule(object, file)
#     793 if module:
#     794     lines = linecache.getlines(file, module.__dict__)
#
# File ~/.local/share/uv/python/cpython-3.8.20-linux-x86_64-gnu/lib/python3.8/inspect.py:751, in getmodule(object, _filename)
#     749     continue
#     750 _filesbymodname[modname] = f
# --> 751 f = getabsfile(module)
#     752 # Always map to the name the module knows itself by
#     753 modulesbyfile[f] = modulesbyfile[
#     754     os.path.realpath(f)] = module.__name__
#
# File ~/.local/share/uv/python/cpython-3.8.20-linux-x86_64-gnu/lib/python3.8/inspect.py:720, in getabsfile(object, _filename)
#     715 """Return an absolute path to the source or compiled file for an object.
#     716
#     717 The idea is for each object to have a unique origin, so this routine
#     718 normalizes the result as much as possible."""
#     719 if _filename is None:
# --> 720     _filename = getsourcefile(object) or getfile(object)
#     721 return os.path.normcase(os.path.abspath(_filename))
#
# File ~/.local/share/uv/python/cpython-3.8.20-linux-x86_64-gnu/lib/python3.8/inspect.py:705, in getsourcefile(object)
#     702 elif any(filename.endswith(s) for s in
#     703              importlib.machinery.EXTENSION_SUFFIXES):
#     704     return None
# --> 705 if os.path.exists(filename):
#     706     return filename
#     707 # only return a non-existent filename if the module has a PEP 302 loader
#
# File ~/.local/share/uv/python/cpython-3.8.20-linux-x86_64-gnu/lib/python3.8/genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
exp_name="example"
output_path="./outputs"
raw_data_path=os.path.join(output_path,f"{exp_name}/{exp_name}_new_data.h5ad")
snc_path=os.path.join(output_path,f'{exp_name}/{exp_name}_sencellgene-epoch{4}.data')
raw_adata=sp.read_h5ad(raw_data_path)

# %%
adata_umap=preprocess_plot(raw_adata)

# %%
generate_umap(adata_umap, 'clusters')

# %%
generate_umap(adata_umap, 'Sample')

# %% [markdown]
# ## SnC analysis

# %%
adata_snc,sub_sencells=load_snc_info(raw_adata,snc_path,threshold=1)
# Out:
# /bmbl_data/chenghao/sencell/test_deepsas/sencell/plot_figure.py:137: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sencell_dict,sen_gene_ls,attention_scores,edge_index_selfloop=torch.load(file_path)
# snc in different cell types:  Counter({'Endothelial cells': 18, 'Alveolar fibroblasts': 14})
# Number of SnC: 32

# %%
bar_plot_condition(sub_sencells)
bar_plot_location(sub_sencells)
# Out:
# Status                Healthy  IPF
# clusters
# Alveolar fibroblasts        6    8
# Endothelial cells           2   16
# Area                  Lower Lobe  Parenchyma  Upper Lobe
# clusters
# Alveolar fibroblasts           7           6           1
# Endothelial cells              8           2           8

# %%
final_table=create_summary_table(adata_snc)
final_table
# Out:
#                              CT # cell # IPF non-SnC # IPF SnC  IPF SnC%  \
# 0                  Plasma cells    108            76         0  0.000000
# 1     Subepithelial fibroblasts     51            50         0  0.000000
# 2          Alveolar fibroblasts    165           102         8  7.272727
# 3           CTHRC1+ fibroblasts     43            23         0  0.000000
# 4                     AT1 cells     98            83         0  0.000000
# 5                     AT2 cells    200           138         0  0.000000
# 6             FABP4 macrophages     45            39         0  0.000000
# 7             Endothelial cells    361           257        16  5.860806
# 8                           SMC     69            48         0  0.000000
# 9                     CD8 cells     33            24         0  0.000000
# 10          Classical Monocytes     69            15         0  0.000000
# 11                    CD4 cells    150           124         0  0.000000
# 12  Endothelial Lymphatic cells     25            15         0  0.000000
# 13         Alveolar macrophages    161            98         0  0.000000
# 14                    RAS cells     41            36         0  0.000000
# 15                     NK cells     48            38         0  0.000000
# 16              Secretory cells     52            34         0  0.000000
# 17                     Ciliated     60            54         0  0.000000
# 18                   Mast cells     34            28         0  0.000000
# 19             SPP1 macrophages     47            22         0  0.000000
# 20                  Adventitial     47            38         0  0.000000
# 21                  Basal cells     36            29         0  0.000000
# 22                    Pericytes     31            22         0  0.000000
# 23                      B cells     11            11         0  0.000000
# 24      Aberrant basaloid cells     14            14         0  0.000000
#
#    # Healthy non-SnC # Healthy SnC  Healthy SnC% # UL non-SnC # UL SnC  ...  \
# 0                 32             0      0.000000           37        0  ...
# 1                  1             0      0.000000           11        0  ...
# 2                 49             6     10.909091           38        1  ...
# 3                 20             0      0.000000           13        0  ...
# 4                 15             0      0.000000           10        0  ...
# 5                 62             0      0.000000           24        0  ...
# 6                  6             0      0.000000           11        0  ...
# 7                 86             2      2.272727           47        8  ...
# 8                 21             0      0.000000           25        0  ...
# 9                  9             0      0.000000            3        0  ...
# 10                54             0      0.000000            5        0  ...
# 11                26             0      0.000000           23        0  ...
# 12                10             0      0.000000           10        0  ...
# 13                63             0      0.000000           35        0  ...
# 14                 5             0      0.000000           22        0  ...
# 15                10             0      0.000000            3        0  ...
# 16                18             0      0.000000           20        0  ...
# 17                 6             0      0.000000           37        0  ...
# 18                 6             0      0.000000           10        0  ...
# 19                25             0      0.000000            8        0  ...
# 20                 9             0      0.000000           22        0  ...
# 21                 7             0      0.000000           26        0  ...
# 22                 9             0      0.000000            3        0  ...
# 23                 0             0      0.000000            5        0  ...
# 24                 0             0      0.000000            6        0  ...
#
#      LL SnC% # Parenchyma non-SnC # Parenchyma SnC  Parenchyma SnC%  \
# 0   0.000000                   32                0         0.000000
# 1   0.000000                    1                0         0.000000
# 2   9.859155                   49                6        10.909091
# 3   0.000000                   20                0         0.000000
# 4   0.000000                   15                0         0.000000
# 5   0.000000                   62                0         0.000000
# 6   0.000000                    6                0         0.000000
# 7   3.669725                   86                2         2.272727
# 8   0.000000                   21                0         0.000000
# 9   0.000000                    9                0         0.000000
# 10  0.000000                   54                0         0.000000
# 11  0.000000                   26                0         0.000000
# 12  0.000000                   10                0         0.000000
# 13  0.000000                   63                0         0.000000
# 14  0.000000                    5                0         0.000000
# 15  0.000000                   10                0         0.000000
# 16  0.000000                   18                0         0.000000
# 17  0.000000                    6                0         0.000000
# 18  0.000000                    6                0         0.000000
# 19  0.000000                   25                0         0.000000
# 20  0.000000                    9                0         0.000000
# 21  0.000000                    7                0         0.000000
# 22  0.000000                    9                0         0.000000
# 23  0.000000                    0                0         0.000000
# 24  0.000000                    0                0         0.000000
#
#    # Young non-SnC # Young SnC  Young SnC% # Old non-SnC # Old SnC  Old SnC%
# 0                0           0         0.0           108         0  0.000000
# 1                0           0         0.0            51         0  0.000000
# 2                3           0         0.0           148        14  8.641975
# 3                0           0         0.0            43         0  0.000000
# 4                2           0         0.0            96         0  0.000000
# 5               12           0         0.0           188         0  0.000000
# 6                1           0         0.0            44         0  0.000000
# 7                5           0         0.0           338        18  5.056180
# 8                0           0         0.0            69         0  0.000000
# 9                0           0         0.0            33         0  0.000000
# 10               3           0         0.0            66         0  0.000000
# 11               0           0         0.0           150         0  0.000000
# 12               0           0         0.0            25         0  0.000000
# 13               9           0         0.0           152         0  0.000000
# 14               1           0         0.0            40         0  0.000000
# 15               0           0         0.0            48         0  0.000000
# 16               1           0         0.0            51         0  0.000000
# 17               0           0         0.0            60         0  0.000000
# 18               1           0         0.0            33         0  0.000000
# 19               6           0         0.0            41         0  0.000000
# 20               0           0         0.0            47         0  0.000000
# 21               0           0         0.0            36         0  0.000000
# 22               0           0         0.0            31         0  0.000000
# 23               0           0         0.0            11         0  0.000000
# 24               0           0         0.0            14         0  0.000000
#
# [25 rows x 23 columns]

# %%
table3_path=os.path.join(output_path,f"{exp_name}/Senescent_Tables/Gene_newTable3_gene_ct_count.csv")
generate_heatmap_snc(adata_snc,
                     table3_path=table3_path,
                     z_score=True)
